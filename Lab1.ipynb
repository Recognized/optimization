# %%
from Lab1 import *

task_1()
# Out:
# {'answer': -0.8392124176025392, 'iterations': 16, 'calc': 32, 'name': 'dichotomy'}
# {'answer': -0.8335092687606812, 'iterations': 19, 'calc': 38, 'name': 'dichotomy'}
# {'answer': -0.8332727256417275, 'iterations': 22, 'calc': 44, 'name': 'dichotomy'}
# {'answer': -0.8333474189322441, 'iterations': 26, 'calc': 52, 'name': 'dichotomy'}
# {'answer': -0.8025962243082503, 'calc': 22, 'iterations': 21, 'name': 'fibonacci'}
# {'answer': -0.833828910893666, 'calc': 27, 'iterations': 26, 'name': 'fibonacci'}
# {'answer': -0.8332151223726167, 'calc': 31, 'iterations': 30, 'name': 'fibonacci'}
# {'answer': -0.8333120496773168, 'calc': 36, 'iterations': 35, 'name': 'fibonacci'}
# {'answer': -0.8244950095527079, 'calc': 23, 'iterations': 21, 'name': 'golden_section'}
# {'answer': -0.8350095631285587, 'calc': 28, 'iterations': 26, 'name': 'golden_section'}
# {'answer': -0.8333970916289906, 'calc': 33, 'iterations': 31, 'name': 'golden_section'}
# ...

# %%
task_2()
# Out:
# {'calc': 572, 'iterations': 11, 'name': 'dichotomy'}
# {'calc': 329, 'iterations': 11, 'name': 'straight'}
# {'calc': 407, 'iterations': 11, 'name': 'golden_section'}
# {'calc': 388, 'iterations': 11, 'name': 'fibonacci'}
# {'calc': 0, 'iterations': 2001, 'name': 'constant_step: 0.001000'}
# {'calc': 107, 'iterations': 37, 'name': 'armiho: e=0.100000, l=1.000000, d=0.950000'}
# {'calc': 260, 'iterations': 5, 'name': 'dichotomy'}
# {'calc': 116, 'iterations': 4, 'name': 'straight'}
# {'calc': 148, 'iterations': 4, 'name': 'golden_section'}
# {'calc': 174, 'iterations': 5, 'name': 'fibonacci'}
# {'calc': 0, 'iterations': 2001, 'name': 'constant_step: 0.001000'}
# {'calc': 658, 'iterations': 102, 'name': 'armiho: e=0.100000, l=1.000000, d=0.950000'}

# %%
task_3()
# Out:
# 100% (625 of 625) |######################| Elapsed Time: 0:59:34 Time:  0:59:34

# %%
task_4a()
task_4b()
# Out:
# alpha = 0.0001 f-score = 0.8374042950513539
# alpha = 0.001 f-score = 0.8081991023708108
# alpha = 0.01 f-score = 0.7977316008072921
# alpha = 0.1 f-score = 0.35114092924619233
# alpha = 1.0 f-score = 0.0
# Best params: 0.0001 0.8374042950513539
# steps = 2002
# time = 882.784 ms
# alpha = 0.0001 f-score = 0.794975541579315
# alpha = 0.001 f-score = 0.8262454212454212
# alpha = 0.01 f-score = 0.8032598032451256
# alpha = 0.1 f-score = 0.3367676767676767
# alpha = 1.0 f-score = 0.0
# Best params: 0.001 0.8262454212454212
# steps = 9
# time = 57.013 ms
